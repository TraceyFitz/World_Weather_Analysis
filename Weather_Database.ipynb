# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations and zip object them with zip() function.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
#The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple. 
#If there are 2000 latitudes and longitudes, there will be 2000 tuples of paired latitudes and longitudes, 
#where each latitude and longitude in a tuple can be accessed by the index of 0 and 1, respectively.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#You can only unzip a zipped tuple once before it is removed from the computer's memory. 
#Make sure you unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Import
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 707

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Open Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=755f33187f86c3f74d9f8ae7856e6b2d

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#Let's use the enumerate() method to get the index of the city for logging purposes 
#and the city for creating an endpoint URL. 
#Add the following code below our counters.

# Loop through all the cities in the list.

#We create the for loop with the enumerate() method and reference the index and the city in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    #In the conditional statement, we check if the remainder of the index divided by 50 is equal to 0 
    #and if the index is greater than or equal to 50. 
    #If the statement is true, then the set_count and the record_count are incremented by 1.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #Inside the conditional statement, we create the URL endpoint for each city, as before. 
    #However, we are removing the blank spaces in the city name and concatenating the city name with, city.replace(" ","+"). 
    #This will find the corresponding weather data for the city instead of finding the weather data for the first part of the city name.


    # Log the URL, record, and set numbers and the city.
    #Also, we add a print statement that tells us the record count and set count, and the city that is being processed.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    #Then above we add one to the record count before the next city is processed.
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        #pass is a general purpose statement to handle all errors encountered & to allow the program to continue.

# Indicate that Data Loading is complete by adding the closing print statement
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | necochea
# Processing Record 4 of Set 1 | tuatapere
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | port lincoln
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | pondicherry
# Processing Record 11 of Set 1 | hambantota
# Processing Record 12 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | saint anthony
# Processing Record 16 of Set 1 | haradok
# Processing Record 17 of Set 1 | gorom-gorom
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | gwanda
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | maraba
# Processing Record 22 of Set 1 | isangel
# Processing Record 23 of Set 1 | vardo
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | charters towers
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | asau
# Processing Record 28 of Set 1 | leningradskiy
# Processing Record 29 of Set 1 | kalamare
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | alanya
# Processing Record 33 of Set 1 | mazara del vallo
# Processing Record 34 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | khatanga
# Processing Record 36 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 1 | utete
# Processing Record 38 of Set 1 | victoria
# Processing Record 39 of Set 1 | brindisi
# Processing Record 40 of Set 1 | jinchang
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | atasu
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | alta floresta
# Processing Record 45 of Set 1 | arona
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | dolores
# Processing Record 48 of Set 1 | moroni
# Processing Record 49 of Set 1 | sola
# Processing Record 50 of Set 1 | kavieng
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | batemans bay
# Processing Record 5 of Set 2 | namatanai
# Processing Record 6 of Set 2 | beringovskiy
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | kalmunai
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | douglas
# Processing Record 15 of Set 2 | impfondo
# Processing Record 16 of Set 2 | pueblo
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | tchibanga
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | rawson
# Processing Record 22 of Set 2 | baruun-urt
# Processing Record 23 of Set 2 | clyde river
# Processing Record 24 of Set 2 | mantua
# Processing Record 25 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 2 | itoman
# Processing Record 27 of Set 2 | cayenne
# Processing Record 28 of Set 2 | tutoia
# Processing Record 29 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | gaya
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 2 | saldanha
# Processing Record 38 of Set 2 | teya
# Processing Record 39 of Set 2 | luderitz
# Processing Record 40 of Set 2 | san patricio
# Processing Record 41 of Set 2 | khuzhir
# Processing Record 42 of Set 2 | maghama
# City not found. Skipping...
# Processing Record 43 of Set 2 | mataura
# Processing Record 44 of Set 2 | luganville
# Processing Record 45 of Set 2 | deputatskiy
# Processing Record 46 of Set 2 | inverness
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | lumasal
# City not found. Skipping...
# Processing Record 49 of Set 2 | kahului
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | fairbanks
# Processing Record 2 of Set 3 | acapulco
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | anloga
# Processing Record 5 of Set 3 | playa vicente
# Processing Record 6 of Set 3 | northam
# Processing Record 7 of Set 3 | codrington
# Processing Record 8 of Set 3 | longyearbyen
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | chippewa falls
# Processing Record 12 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | constitucion
# Processing Record 17 of Set 3 | pevek
# Processing Record 18 of Set 3 | qaqortoq
# Processing Record 19 of Set 3 | semey
# Processing Record 20 of Set 3 | bambous virieux
# Processing Record 21 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 3 | nanortalik
# Processing Record 23 of Set 3 | ulety
# Processing Record 24 of Set 3 | hermosillo
# Processing Record 25 of Set 3 | westport
# Processing Record 26 of Set 3 | nelson bay
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | rundu
# Processing Record 29 of Set 3 | bandarbeyla
# Processing Record 30 of Set 3 | haines junction
# Processing Record 31 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 3 | prince rupert
# Processing Record 33 of Set 3 | sitka
# Processing Record 34 of Set 3 | xadani
# City not found. Skipping...
# Processing Record 35 of Set 3 | bonthe
# Processing Record 36 of Set 3 | vestmanna
# Processing Record 37 of Set 3 | klaksvik
# Processing Record 38 of Set 3 | fortuna
# Processing Record 39 of Set 3 | san policarpo
# Processing Record 40 of Set 3 | devrek
# Processing Record 41 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 3 | ilulissat
# Processing Record 43 of Set 3 | bengkalis
# City not found. Skipping...
# Processing Record 44 of Set 3 | ahipara
# Processing Record 45 of Set 3 | coihaique
# Processing Record 46 of Set 3 | rio gallegos
# Processing Record 47 of Set 3 | tumpat
# Processing Record 48 of Set 3 | saravena
# Processing Record 49 of Set 3 | mitsamiouli
# Processing Record 50 of Set 3 | dabhoi
# Processing Record 1 of Set 4 | camana
# Processing Record 2 of Set 4 | praia da vitoria
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | takoradi
# Processing Record 5 of Set 4 | ostrovnoy
# Processing Record 6 of Set 4 | nemuro
# Processing Record 7 of Set 4 | beloha
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | vestmannaeyjar
# Processing Record 10 of Set 4 | lompoc
# Processing Record 11 of Set 4 | faya
# Processing Record 12 of Set 4 | husavik
# Processing Record 13 of Set 4 | aswan
# Processing Record 14 of Set 4 | barrow
# Processing Record 15 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 17 of Set 4 | mayo
# Processing Record 18 of Set 4 | kenai
# Processing Record 19 of Set 4 | lorengau
# Processing Record 20 of Set 4 | porto novo
# Processing Record 21 of Set 4 | bezhetsk
# Processing Record 22 of Set 4 | hasaki
# Processing Record 23 of Set 4 | maymanak
# City not found. Skipping...
# Processing Record 24 of Set 4 | ostersund
# Processing Record 25 of Set 4 | vaini
# Processing Record 26 of Set 4 | walvis bay
# Processing Record 27 of Set 4 | belaya gora
# Processing Record 28 of Set 4 | nabire
# Processing Record 29 of Set 4 | the valley
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | vaitape
# Processing Record 32 of Set 4 | lagos
# Processing Record 33 of Set 4 | gidam
# Processing Record 34 of Set 4 | nuuk
# Processing Record 35 of Set 4 | srednekolymsk
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | saryozek
# Processing Record 38 of Set 4 | saint-leu
# Processing Record 39 of Set 4 | arlit
# Processing Record 40 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 4 | katobu
# Processing Record 42 of Set 4 | mehamn
# Processing Record 43 of Set 4 | altayskoye
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | skelleftea
# Processing Record 46 of Set 4 | linhares
# Processing Record 47 of Set 4 | norman wells
# Processing Record 48 of Set 4 | la ronge
# Processing Record 49 of Set 4 | urbano santos
# Processing Record 50 of Set 4 | bengkulu
# Processing Record 1 of Set 5 | oistins
# Processing Record 2 of Set 5 | samarai
# Processing Record 3 of Set 5 | lagoa
# Processing Record 4 of Set 5 | gat
# Processing Record 5 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 5 | kavaratti
# Processing Record 7 of Set 5 | eugene
# Processing Record 8 of Set 5 | palmer
# Processing Record 9 of Set 5 | otradnoye
# Processing Record 10 of Set 5 | ha giang
# Processing Record 11 of Set 5 | cabedelo
# Processing Record 12 of Set 5 | tsumeb
# Processing Record 13 of Set 5 | kruisfontein
# Processing Record 14 of Set 5 | vila velha
# Processing Record 15 of Set 5 | atambua
# Processing Record 16 of Set 5 | mathathane
# Processing Record 17 of Set 5 | ukiah
# Processing Record 18 of Set 5 | noumea
# Processing Record 19 of Set 5 | jadu
# Processing Record 20 of Set 5 | flinders
# Processing Record 21 of Set 5 | dong hoi
# Processing Record 22 of Set 5 | marovoay
# Processing Record 23 of Set 5 | eureka
# Processing Record 24 of Set 5 | lata
# Processing Record 25 of Set 5 | yenotayevka
# Processing Record 26 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 5 | russkiy aktash
# Processing Record 28 of Set 5 | saskylakh
# Processing Record 29 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 5 | shakawe
# Processing Record 31 of Set 5 | jalu
# Processing Record 32 of Set 5 | castro
# Processing Record 33 of Set 5 | oussouye
# Processing Record 34 of Set 5 | provideniya
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | zhigansk
# Processing Record 37 of Set 5 | el banco
# Processing Record 38 of Set 5 | zhanaozen
# Processing Record 39 of Set 5 | surt
# Processing Record 40 of Set 5 | mount gambier
# Processing Record 41 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 5 | hithadhoo
# Processing Record 43 of Set 5 | skara
# Processing Record 44 of Set 5 | daru
# Processing Record 45 of Set 5 | minab
# Processing Record 46 of Set 5 | letavertes
# Processing Record 47 of Set 5 | sambava
# Processing Record 48 of Set 5 | cherskiy
# Processing Record 49 of Set 5 | rebrikha
# Processing Record 50 of Set 5 | manjacaze
# Processing Record 1 of Set 6 | male
# Processing Record 2 of Set 6 | tecoanapa
# Processing Record 3 of Set 6 | batagay-alyta
# Processing Record 4 of Set 6 | udachnyy
# Processing Record 5 of Set 6 | miraflores
# Processing Record 6 of Set 6 | teknaf
# Processing Record 7 of Set 6 | bathsheba
# Processing Record 8 of Set 6 | zhigalovo
# Processing Record 9 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 6 | vao
# Processing Record 11 of Set 6 | lavrentiya
# Processing Record 12 of Set 6 | turukhansk
# Processing Record 13 of Set 6 | port hedland
# Processing Record 14 of Set 6 | russell
# Processing Record 15 of Set 6 | mendi
# Processing Record 16 of Set 6 | larsnes
# Processing Record 17 of Set 6 | esperance
# Processing Record 18 of Set 6 | yenagoa
# Processing Record 19 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 6 | nantucket
# Processing Record 21 of Set 6 | leshukonskoye
# Processing Record 22 of Set 6 | denpasar
# Processing Record 23 of Set 6 | burnie
# Processing Record 24 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 6 | juneau
# Processing Record 26 of Set 6 | bilibino
# Processing Record 27 of Set 6 | khandyga
# Processing Record 28 of Set 6 | cidreira
# Processing Record 29 of Set 6 | katsuura
# Processing Record 30 of Set 6 | yabrud
# Processing Record 31 of Set 6 | egvekinot
# Processing Record 32 of Set 6 | itaituba
# Processing Record 33 of Set 6 | saint george
# Processing Record 34 of Set 6 | yerofey pavlovich
# Processing Record 35 of Set 6 | sabzevar
# Processing Record 36 of Set 6 | monzon
# Processing Record 37 of Set 6 | vila franca do campo
# Processing Record 38 of Set 6 | salalah
# Processing Record 39 of Set 6 | hervey bay
# Processing Record 40 of Set 6 | bull savanna
# Processing Record 41 of Set 6 | kirakira
# Processing Record 42 of Set 6 | mananara
# Processing Record 43 of Set 6 | baykit
# Processing Record 44 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 6 | karratha
# Processing Record 46 of Set 6 | lincoln
# Processing Record 47 of Set 6 | tilichiki
# Processing Record 48 of Set 6 | ponta do sol
# Processing Record 49 of Set 6 | airai
# Processing Record 50 of Set 6 | yialos
# City not found. Skipping...
# Processing Record 1 of Set 7 | araceli
# Processing Record 2 of Set 7 | souillac
# Processing Record 3 of Set 7 | plettenberg bay
# Processing Record 4 of Set 7 | ayan
# Processing Record 5 of Set 7 | viransehir
# Processing Record 6 of Set 7 | preobrazheniye
# Processing Record 7 of Set 7 | zhicheng
# Processing Record 8 of Set 7 | filadelfia
# Processing Record 9 of Set 7 | pangnirtung
# Processing Record 10 of Set 7 | pacific grove
# Processing Record 11 of Set 7 | whitianga
# Processing Record 12 of Set 7 | gladstone
# Processing Record 13 of Set 7 | cockburn town
# Processing Record 14 of Set 7 | san rafael
# Processing Record 15 of Set 7 | pasni
# Processing Record 16 of Set 7 | muros
# Processing Record 17 of Set 7 | kungurtug
# Processing Record 18 of Set 7 | katherine
# Processing Record 19 of Set 7 | laguna
# Processing Record 20 of Set 7 | port hardy
# Processing Record 21 of Set 7 | tunduma
# Processing Record 22 of Set 7 | dongsheng
# Processing Record 23 of Set 7 | rassvet
# Processing Record 24 of Set 7 | padang
# Processing Record 25 of Set 7 | wadi musa
# Processing Record 26 of Set 7 | faanui
# Processing Record 27 of Set 7 | saint-philippe
# Processing Record 28 of Set 7 | chaman
# Processing Record 29 of Set 7 | banda aceh
# Processing Record 30 of Set 7 | yining
# Processing Record 31 of Set 7 | nata
# Processing Record 32 of Set 7 | divnomorskoye
# Processing Record 33 of Set 7 | amga
# Processing Record 34 of Set 7 | hengyang
# Processing Record 35 of Set 7 | constantine
# Processing Record 36 of Set 7 | dickinson
# Processing Record 37 of Set 7 | phra phutthabat
# Processing Record 38 of Set 7 | hun
# Processing Record 39 of Set 7 | mezhdurechensk
# Processing Record 40 of Set 7 | taitung
# Processing Record 41 of Set 7 | kaitangata
# Processing Record 42 of Set 7 | bocaiuva
# Processing Record 43 of Set 7 | coos bay
# Processing Record 44 of Set 7 | winchester
# Processing Record 45 of Set 7 | le pradet
# Processing Record 46 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 7 | harsin
# Processing Record 48 of Set 7 | tsiroanomandidy
# Processing Record 49 of Set 7 | kang
# Processing Record 50 of Set 7 | diban
# Processing Record 1 of Set 8 | basco
# Processing Record 2 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 8 | sungairaya
# Processing Record 4 of Set 8 | san cristobal
# Processing Record 5 of Set 8 | great yarmouth
# Processing Record 6 of Set 8 | raudeberg
# Processing Record 7 of Set 8 | tari
# Processing Record 8 of Set 8 | negotino-polosko
# City not found. Skipping...
# Processing Record 9 of Set 8 | caravelas
# Processing Record 10 of Set 8 | kuala terengganu
# Processing Record 11 of Set 8 | sao filipe
# Processing Record 12 of Set 8 | namibe
# Processing Record 13 of Set 8 | morro bay
# Processing Record 14 of Set 8 | dwarka
# Processing Record 15 of Set 8 | staryy nadym
# Processing Record 16 of Set 8 | kolokani
# Processing Record 17 of Set 8 | cibitung
# Processing Record 18 of Set 8 | peleduy
# Processing Record 19 of Set 8 | troitsko-pechorsk
# Processing Record 20 of Set 8 | tiznit
# Processing Record 21 of Set 8 | taltal
# Processing Record 22 of Set 8 | lannion
# Processing Record 23 of Set 8 | littlehampton
# Processing Record 24 of Set 8 | paita
# Processing Record 25 of Set 8 | chazuta
# Processing Record 26 of Set 8 | ladario
# Processing Record 27 of Set 8 | bukachacha
# Processing Record 28 of Set 8 | fecamp
# Processing Record 29 of Set 8 | los llanos de aridane
# Processing Record 30 of Set 8 | boguchany
# Processing Record 31 of Set 8 | hornbaek
# Processing Record 32 of Set 8 | dargaville
# Processing Record 33 of Set 8 | antofagasta
# Processing Record 34 of Set 8 | kiomboi
# Processing Record 35 of Set 8 | inta
# Processing Record 36 of Set 8 | torbay
# Processing Record 37 of Set 8 | kamenka
# Processing Record 38 of Set 8 | oksfjord
# Processing Record 39 of Set 8 | amuntai
# Processing Record 40 of Set 8 | zhitikara
# City not found. Skipping...
# Processing Record 41 of Set 8 | trinidad
# Processing Record 42 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 43 of Set 8 | wagar
# Processing Record 44 of Set 8 | merauke
# Processing Record 45 of Set 8 | aracaju
# Processing Record 46 of Set 8 | villeneuve-le-roi
# Processing Record 47 of Set 8 | cabo san lucas
# Processing Record 48 of Set 8 | guantanamo
# Processing Record 49 of Set 8 | acajutla
# Processing Record 50 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 9 | evensk
# Processing Record 2 of Set 9 | lianzhou
# Processing Record 3 of Set 9 | sakakah
# Processing Record 4 of Set 9 | sao joao da barra
# Processing Record 5 of Set 9 | guerrero negro
# Processing Record 6 of Set 9 | dingle
# Processing Record 7 of Set 9 | kloulklubed
# Processing Record 8 of Set 9 | adilpur
# Processing Record 9 of Set 9 | agadez
# Processing Record 10 of Set 9 | vostok
# Processing Record 11 of Set 9 | shaoyang
# Processing Record 12 of Set 9 | porbandar
# Processing Record 13 of Set 9 | inhambane
# Processing Record 14 of Set 9 | tongzi
# Processing Record 15 of Set 9 | lubango
# Processing Record 16 of Set 9 | auki
# Processing Record 17 of Set 9 | luanda
# Processing Record 18 of Set 9 | aleksinac
# Processing Record 19 of Set 9 | amapa
# Processing Record 20 of Set 9 | loanda
# Processing Record 21 of Set 9 | korla
# Processing Record 22 of Set 9 | druzhba
# Processing Record 23 of Set 9 | gimli
# Processing Record 24 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 25 of Set 9 | dudinka
# Processing Record 26 of Set 9 | rosetta
# Processing Record 27 of Set 9 | viedma
# Processing Record 28 of Set 9 | athens
# Processing Record 29 of Set 9 | quatre cocos
# Processing Record 30 of Set 9 | arica
# Processing Record 31 of Set 9 | karaton
# Processing Record 32 of Set 9 | coquimbo
# Processing Record 33 of Set 9 | vila
# Processing Record 34 of Set 9 | kieta
# Processing Record 35 of Set 9 | west bay
# Processing Record 36 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 9 | mushabani
# Processing Record 38 of Set 9 | tambopata
# Processing Record 39 of Set 9 | cairns
# Processing Record 40 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 9 | nome
# Processing Record 42 of Set 9 | kaohsiung
# Processing Record 43 of Set 9 | meulaboh
# Processing Record 44 of Set 9 | pinyug
# Processing Record 45 of Set 9 | puerto escondido
# Processing Record 46 of Set 9 | kedrovyy
# Processing Record 47 of Set 9 | talcahuano
# Processing Record 48 of Set 9 | aviles
# Processing Record 49 of Set 9 | willowmore
# Processing Record 50 of Set 9 | san jeronimo
# Processing Record 1 of Set 10 | ayorou
# Processing Record 2 of Set 10 | wanaka
# Processing Record 3 of Set 10 | peabiru
# Processing Record 4 of Set 10 | matara
# Processing Record 5 of Set 10 | alofi
# Processing Record 6 of Set 10 | burica
# City not found. Skipping...
# Processing Record 7 of Set 10 | lismore
# Processing Record 8 of Set 10 | hit
# Processing Record 9 of Set 10 | arak
# Processing Record 10 of Set 10 | iquitos
# Processing Record 11 of Set 10 | yian
# City not found. Skipping...
# Processing Record 12 of Set 10 | coahuayana
# Processing Record 13 of Set 10 | moca
# Processing Record 14 of Set 10 | guajara-mirim
# City not found. Skipping...
# Processing Record 15 of Set 10 | neya
# Processing Record 16 of Set 10 | zachepylivka
# Processing Record 17 of Set 10 | acarau
# Processing Record 18 of Set 10 | port-gentil
# Processing Record 19 of Set 10 | svetlyy
# Processing Record 20 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 10 | koutsouras
# Processing Record 22 of Set 10 | tura
# Processing Record 23 of Set 10 | deniliquin
# Processing Record 24 of Set 10 | george town
# Processing Record 25 of Set 10 | waingapu
# Processing Record 26 of Set 10 | akdepe
# Processing Record 27 of Set 10 | ordynskoye
# Processing Record 28 of Set 10 | hualmay
# Processing Record 29 of Set 10 | seoul
# Processing Record 30 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 31 of Set 10 | montepuez
# Processing Record 32 of Set 10 | kiama
# Processing Record 33 of Set 10 | aksu
# Processing Record 34 of Set 10 | axim
# Processing Record 35 of Set 10 | krabi
# Processing Record 36 of Set 10 | bose
# Processing Record 37 of Set 10 | shahrud
# Processing Record 38 of Set 10 | lamu
# Processing Record 39 of Set 10 | north bend
# Processing Record 40 of Set 10 | sumbe
# Processing Record 41 of Set 10 | el dorado
# Processing Record 42 of Set 10 | maniitsoq
# Processing Record 43 of Set 10 | kande
# Processing Record 44 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 10 | suba
# Processing Record 47 of Set 10 | nova granada
# Processing Record 48 of Set 10 | abu dhabi
# Processing Record 49 of Set 10 | itarema
# Processing Record 50 of Set 10 | weihai
# Processing Record 1 of Set 11 | alice springs
# Processing Record 2 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 11 | escarcega
# Processing Record 4 of Set 11 | bundaberg
# Processing Record 5 of Set 11 | bodden town
# Processing Record 6 of Set 11 | paracale
# Processing Record 7 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 11 | golden
# Processing Record 9 of Set 11 | richards bay
# Processing Record 10 of Set 11 | grindavik
# Processing Record 11 of Set 11 | jiuquan
# Processing Record 12 of Set 11 | molteno
# Processing Record 13 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 14 of Set 11 | emerald
# Processing Record 15 of Set 11 | borogontsy
# Processing Record 16 of Set 11 | elko
# Processing Record 17 of Set 11 | ust-tsilma
# Processing Record 18 of Set 11 | hwange
# Processing Record 19 of Set 11 | les cayes
# Processing Record 20 of Set 11 | tonantins
# Processing Record 21 of Set 11 | kropotkin
# Processing Record 22 of Set 11 | nhulunbuy
# Processing Record 23 of Set 11 | tazovskiy
# Processing Record 24 of Set 11 | marsh harbour
# Processing Record 25 of Set 11 | bulgan
# Processing Record 26 of Set 11 | kavali
# Processing Record 27 of Set 11 | hay river
# Processing Record 28 of Set 11 | coihueco
# Processing Record 29 of Set 11 | iqaluit
# Processing Record 30 of Set 11 | taikang
# Processing Record 31 of Set 11 | bouca
# Processing Record 32 of Set 11 | buala
# Processing Record 33 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 11 | tarakan
# Processing Record 35 of Set 11 | dunedin
# Processing Record 36 of Set 11 | poronaysk
# Processing Record 37 of Set 11 | elban
# Processing Record 38 of Set 11 | panzhihua
# Processing Record 39 of Set 11 | wuda
# Processing Record 40 of Set 11 | batagay
# Processing Record 41 of Set 11 | kununurra
# Processing Record 42 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 43 of Set 11 | zaraza
# Processing Record 44 of Set 11 | aleksandrovskiy zavod
# Processing Record 45 of Set 11 | teguldet
# Processing Record 46 of Set 11 | la sarre
# Processing Record 47 of Set 11 | kilinochchi
# Processing Record 48 of Set 11 | jeremie
# Processing Record 49 of Set 11 | bubaque
# Processing Record 50 of Set 11 | belyy yar
# Processing Record 1 of Set 12 | najran
# Processing Record 2 of Set 12 | salinopolis
# Processing Record 3 of Set 12 | titay
# Processing Record 4 of Set 12 | sangar
# Processing Record 5 of Set 12 | qinzhou
# Processing Record 6 of Set 12 | kiunga
# Processing Record 7 of Set 12 | si chiang mai
# Processing Record 8 of Set 12 | makakilo city
# Processing Record 9 of Set 12 | puerto del rosario
# Processing Record 10 of Set 12 | krasnoselkup
# Processing Record 11 of Set 12 | verkhnevilyuysk
# Processing Record 12 of Set 12 | tombouctou
# Processing Record 13 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 12 | bokoro
# Processing Record 15 of Set 12 | maningrida
# Processing Record 16 of Set 12 | pingdu
# Processing Record 17 of Set 12 | ketchikan
# Processing Record 18 of Set 12 | geraldton
# Processing Record 19 of Set 12 | dewas
# Processing Record 20 of Set 12 | pangkalanbuun
# Processing Record 21 of Set 12 | preeceville
# Processing Record 22 of Set 12 | camacha
# Processing Record 23 of Set 12 | floro
# Processing Record 24 of Set 12 | adrar
# Processing Record 25 of Set 12 | tubuala
# Processing Record 26 of Set 12 | saint-denis
# Processing Record 27 of Set 12 | chenzhou
# Processing Record 28 of Set 12 | la macarena
# Processing Record 29 of Set 12 | havelock
# Processing Record 30 of Set 12 | kutum
# Processing Record 31 of Set 12 | pedernales
# Processing Record 32 of Set 12 | dawei
# Processing Record 33 of Set 12 | uyuni
# Processing Record 34 of Set 12 | ginda
# Processing Record 35 of Set 12 | gushikawa
# Processing Record 36 of Set 12 | maumere
# Processing Record 37 of Set 12 | salekhard
# Processing Record 38 of Set 12 | sabang
# Processing Record 39 of Set 12 | zhuanghe
# Processing Record 40 of Set 12 | pailon
# Processing Record 41 of Set 12 | bartica
# Processing Record 42 of Set 12 | nouadhibou
# Processing Record 43 of Set 12 | kultuk
# Processing Record 44 of Set 12 | payakumbuh
# Processing Record 45 of Set 12 | chimore
# Processing Record 46 of Set 12 | rostovka
# Processing Record 47 of Set 12 | pastavy
# Processing Record 48 of Set 12 | manono
# Processing Record 49 of Set 12 | wagga wagga
# Processing Record 50 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 1 of Set 13 | virginia beach
# Processing Record 2 of Set 13 | tselinnoye
# Processing Record 3 of Set 13 | doha
# Processing Record 4 of Set 13 | lahad datu
# Processing Record 5 of Set 13 | tocopilla
# Processing Record 6 of Set 13 | edd
# Processing Record 7 of Set 13 | varzea grande
# Processing Record 8 of Set 13 | pundaguitan
# Processing Record 9 of Set 13 | zhaodong
# Processing Record 10 of Set 13 | luau
# Processing Record 11 of Set 13 | adre
# Processing Record 12 of Set 13 | tabriz
# Processing Record 13 of Set 13 | pachperwa
# Processing Record 14 of Set 13 | nioro
# Processing Record 15 of Set 13 | oleksandrivka
# Processing Record 16 of Set 13 | aktau
# Processing Record 17 of Set 13 | iskateley
# Processing Record 18 of Set 13 | xining
# Processing Record 19 of Set 13 | kisaran
# Processing Record 20 of Set 13 | olafsvik
# Processing Record 21 of Set 13 | hofn
# Processing Record 22 of Set 13 | vikhorevka
# Processing Record 23 of Set 13 | khani
# Processing Record 24 of Set 13 | kargasok
# Processing Record 25 of Set 13 | whitehorse
# Processing Record 26 of Set 13 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 27 of Set 13 | zaigrayevo
# Processing Record 28 of Set 13 | ambatondrazaka
# Processing Record 29 of Set 13 | lisakovsk
# Processing Record 30 of Set 13 | vladyslavivka
# Processing Record 31 of Set 13 | astana
# Processing Record 32 of Set 13 | caronport
# Processing Record 33 of Set 13 | college
# Processing Record 34 of Set 13 | victor harbor
# Processing Record 35 of Set 13 | vrede
# Processing Record 36 of Set 13 | porto walter
# Processing Record 37 of Set 13 | placerville
# Processing Record 38 of Set 13 | barra do garcas
# Processing Record 39 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 13 | golden gate
# Processing Record 41 of Set 13 | calvinia
# Processing Record 42 of Set 13 | champerico
# Processing Record 43 of Set 13 | harper
# Processing Record 44 of Set 13 | leh
# Processing Record 45 of Set 13 | limbazi
# Processing Record 46 of Set 13 | salto
# Processing Record 47 of Set 13 | senador jose porfirio
# Processing Record 48 of Set 13 | omboue
# Processing Record 49 of Set 13 | sasovo
# Processing Record 50 of Set 13 | atikokan
# Processing Record 1 of Set 14 | laranjeiras
# Processing Record 2 of Set 14 | madras
# Processing Record 3 of Set 14 | manavalakurichi
# Processing Record 4 of Set 14 | gornopravdinsk
# Processing Record 5 of Set 14 | malakwal
# Processing Record 6 of Set 14 | kaniama
# Processing Record 7 of Set 14 | pesochnoye
# Processing Record 8 of Set 14 | maceio
# Processing Record 9 of Set 14 | pisco
# Processing Record 10 of Set 14 | kachiry
# Processing Record 11 of Set 14 | vylgort
# City not found. Skipping...
# Processing Record 12 of Set 14 | tecolutla
# Processing Record 13 of Set 14 | piopio
# Processing Record 14 of Set 14 | gamba
# Processing Record 15 of Set 14 | camocim
# Processing Record 16 of Set 14 | burhar
# Processing Record 17 of Set 14 | zyryanka
# Processing Record 18 of Set 14 | aklavik
# Processing Record 19 of Set 14 | shingu
# Processing Record 20 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 14 | bowen
# Processing Record 22 of Set 14 | luz
# Processing Record 23 of Set 14 | bairiki
# Processing Record 24 of Set 14 | boda
# Processing Record 25 of Set 14 | abu kamal
# Processing Record 26 of Set 14 | tevriz
# Processing Record 27 of Set 14 | saint-joseph
# Processing Record 28 of Set 14 | sorland
# Processing Record 29 of Set 14 | komsomolskiy
# Processing Record 30 of Set 14 | araouane
# Processing Record 31 of Set 14 | kazachinskoye
# Processing Record 32 of Set 14 | sao miguel do araguaia
# Processing Record 33 of Set 14 | naples
# Processing Record 34 of Set 14 | yumen
# Processing Record 35 of Set 14 | ishigaki
# Processing Record 36 of Set 14 | marawi
# Processing Record 37 of Set 14 | cuauhtemoc
# Processing Record 38 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 39 of Set 14 | manta
# Processing Record 40 of Set 14 | kupang
# Processing Record 41 of Set 14 | khandbari
# Processing Record 42 of Set 14 | erzin
# Processing Record 43 of Set 14 | antalaha
# Processing Record 44 of Set 14 | santa cruz del sur
# Processing Record 45 of Set 14 | jasper
# Processing Record 46 of Set 14 | birao
# Processing Record 47 of Set 14 | wasilla
# Processing Record 48 of Set 14 | rodbyhavn
# Processing Record 49 of Set 14 | ekhabi
# Processing Record 50 of Set 14 | yerbogachen
# Processing Record 1 of Set 15 | pachino
# Processing Record 2 of Set 15 | altoona
# Processing Record 3 of Set 15 | urumqi
# Processing Record 4 of Set 15 | san miguel
# Processing Record 5 of Set 15 | half moon bay
# Processing Record 6 of Set 15 | wanning
# Processing Record 7 of Set 15 | bodaybo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0         Qaanaaq  77.4840  -69.3632      8.82     overcast clouds        88
# 1       Busselton -33.6500  115.3333     63.21           clear sky        77
# 2        Necochea -38.5473  -58.7368     76.32           clear sky        41
# 3       Tuatapere -46.1333  167.6833     57.00     overcast clouds        94
# 4  Port Elizabeth -33.9180   25.5701     84.09    scattered clouds        51
# 5           Bluff -46.6000  168.3333     59.18     overcast clouds        82
# 6     Port Alfred -33.5906   26.8910     88.18     overcast clouds        40
# 7    Port Lincoln -34.7333  135.8667     61.95           clear sky        88
# 8          Kodiak  57.7900 -152.4072     38.71                mist       100
# 9     Pondicherry  11.9300   79.8300     82.36           clear sky        82
#
#    Cloudiness  Wind Speed Country                 Date
# 0          97        1.28      GL  2022-03-28 16:07:28
# 1           7       14.43      AU  2022-03-28 16:07:28
# 2           0       15.08      AR  2022-03-28 16:07:28
# 3         100        1.97      NZ  2022-03-28 16:07:29
# 4          45       11.54      ZA  2022-03-28 16:07:25
# 5         100        6.71      NZ  2022-03-28 16:07:29
# 6          95        1.99      ZA  2022-03-28 16:07:29
# 7           2        7.40      AU  2022-03-28 16:07:30
# 8         100       13.80      US  2022-03-28 16:03:15
# 9           0       11.65      IN  2022-03-28 16:07:30

# %%
#Next reorder the columns as City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed and Current Description, so they are easy to read.
#Recall that to reorder the columns, we assign a variable to an array of the columns in the order we want them to appear:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]
#Then, we assign a new or the same DataFrame with new column order:
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Qaanaaq      GL  77.4840  -69.3632      8.82        88
# 1         Busselton      AU -33.6500  115.3333     63.21        77
# 2          Necochea      AR -38.5473  -58.7368     76.32        41
# 3         Tuatapere      NZ -46.1333  167.6833     57.00        94
# 4    Port Elizabeth      ZA -33.9180   25.5701     84.09        51
# ..              ...     ...      ...       ...       ...       ...
# 645          Urumqi      CN  43.8010   87.6005     38.35        75
# 646      San Miguel      SV  13.4833  -88.1833     87.46        43
# 647   Half Moon Bay      US  37.4636 -122.4286     55.31        92
# 648         Wanning      CN  18.8003  110.3967     71.06        92
# 649         Bodaybo      RU  57.8506  114.1933     10.74        97
#
#      Cloudiness  Wind Speed Current Description
# 0            97        1.28     overcast clouds
# 1             7       14.43           clear sky
# 2             0       15.08           clear sky
# 3           100        1.97     overcast clouds
# 4            45       11.54    scattered clouds
# ..          ...         ...                 ...
# 645           0        4.47           clear sky
# 646           0        4.61           clear sky
# 647           0        9.22           clear sky
# 648         100        9.08     overcast clouds
# 649         100        2.71     overcast clouds
#
# [650 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
